# %% [markdown]
# # My Second Notebook

# %% [markdown]
# ## Pandas: Data Framework Library

# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('data/Public_Recycling_Bins.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 6 columns):
# Borough           545 non-null object
# Site type         545 non-null object
# Park/Site Name    545 non-null object
# Address           540 non-null object
# Latitude          544 non-null float64
# Longitude         544 non-null float64
# dtypes: float64(2), object(4)
# memory usage: 25.6+ KB

# %%
df.head()
# Out:
#   Borough    Site type         Park/Site Name  \
# 0   Bronx  Subproperty         227th St. Plgd
# 1   Bronx  Subproperty    Allerton Ballfields
# 2   Bronx      Outdoor  Arthur Ave & E 187 St
# 3   Bronx     Outdoor         Barstow Mansion
# 4   Bronx  Subproperty     Bradley Playground
#
#                            Address   Latitude  Longitude
# 0       E 227 St/Bronx River Pkway  40.890849 -73.864224
# 1     Allerton Ave & Moshulu Pkway  40.848891 -73.877128
# 2              Arthur Ave & 187 St  40.855570 -73.887565
# 3  895 Shore Road, Pelham Bay Park  40.871864 -73.805549
# 4           2001-2017 Bronx Park E  40.851889 -73.868549

# %%
nycwifi = pd.read_csv('data/NYC_Wi-Fi_Hotspot_Locations.csv')

# %%
nycwifi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3179 entries, 0 to 3178
# Data columns (total 29 columns):
# OBJECTID                3179 non-null int64
# Borough                 3179 non-null object
# Type                    3179 non-null object
# Provider                3179 non-null object
# Name                    2921 non-null object
# Location                3179 non-null object
# Latitude                3179 non-null float64
# Longitude               3179 non-null float64
# X                       3179 non-null float64
# Y                       3179 non-null float64
# Location_T              3179 non-null object
# Remarks                 2608 non-null object
# City                    3179 non-null object
# SSID                    3179 non-null object
# SourceID                2090 non-null object
# Activated               1743 non-null object
# BoroCode                3179 non-null int64
# BoroName                3179 non-null object
# ...

# %%
nycwifi.head()
# Out:
#    OBJECTID Borough  Type          Provider  \
# 0      8641      QU  Free  Spot On Networks
# 1      8642      QU  Free  Spot On Networks
# 2      8643      QU  Free  Spot On Networks
# 3      8644      QU  Free  Spot On Networks
# 4      8645      QU  Free  Spot On Networks
#
#                                              Name         Location   Latitude  \
# 0  QUEENS BRIDGE - JACOB A. RIIS Settlement House  10-25 41 AVENUE  40.755727
# 1  QUEENS BRIDGE - JACOB A. RIIS Settlement House  10-43 41 AVENUE  40.755333
# 2  QUEENS BRIDGE - JACOB A. RIIS Settlement House  10-05 41 AVENUE  40.755751
# 3  QUEENS BRIDGE - JACOB A. RIIS Settlement House  10-05 41 AVENUE  40.755751
# 4  QUEENS BRIDGE - JACOB A. RIIS Settlement House  10-05 41 AVENUE  40.755751
#
#    Longitude              X              Y  \
# 0 -73.944583  999603.226193  214613.274574
# 1 -73.944131  999728.543891  214469.807142
# 2 -73.945166  999441.701155  214621.916908
# 3 -73.945166  999441.701155  214621.916908
# ...

# %%
nycwifi.tail()
# Out:
#       OBJECTID Borough  Type              Provider          Name  \
# 3174      7517      MN  Free  LinkNYC - Citybridge  mn-06-121418
# 3175      7518      MN  Free  LinkNYC - Citybridge  mn-06-121538
# 3176      7519      MN  Free  LinkNYC - Citybridge  mn-06-121413
# 3177      7520      MN  Free  LinkNYC - Citybridge  mn-06-121790
# 3178      7521      MN  Free  LinkNYC - Citybridge  mn-06-121792
#
#                 Location   Latitude  Longitude              X              Y  \
# 3174        767 2 AVENUE  40.749292 -73.972751  991800.157911  212265.048196
# 3175  300 EAST 45 STREET  40.751632 -73.970657  992379.902749  213117.969691
# 3176        857 2 AVENUE  40.752343 -73.970524  992416.828885  213376.880292
# 3177  300 EAST 48 STREET  40.753496 -73.969261  992766.495811  213797.086649
# 3178  300 EAST 49 STREET  40.754138 -73.968836  992884.162380  214031.029651
#
#                          ...                                       NTAName  \
# ...

# %%
nycwifi.groupby('Borough').count()
# Out:
#          OBJECTID  Type  Provider  Name  Location  Latitude  Longitude     X  \
# Borough
# BK            694   694       694   594       694       694        694   694
# BX            297   297       297   297       297       297        297   297
# MN           1577  1577      1577  1419      1577      1577       1577  1577
# QU            516   516       516   516       516       516        516   516
# SI             95    95        95    95        95        95         95    95
#
#             Y  Location_T          ...           NTAName  CounDist  Postcode  \
# Borough                            ...
# BK        694         694          ...               694       694       694
# BX        297         297          ...               297       297       297
# MN       1577        1577          ...              1577      1577      1577
# QU        516         516          ...               516       516       516
# ...

# %%
nycwifi['Borough'] == 'MN'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14       True
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 3149    False
# 3150    False
# 3151    False
# 3152    False
# 3153    False
# 3154    False
# 3155    False
# 3156     True
# 3157     True
# 3158     True
# 3159     True
# 3160    False
# 3161     True
# 3162     True
# 3163     True
# 3164     True
# 3165     True
# 3166     True
# 3167     True
# 3168     True
# 3169     True
# 3170     True
# 3171     True
# 3172     True
# 3173     True
# 3174     True
# 3175     True
# 3176     True
# 3177     True
# 3178     True
# ...

# %%
nycwifi[nycwifi['Borough'] == 'MN']
# Out:
#       OBJECTID Borough          Type              Provider  \
# 14         474      MN          Free                Harlem
# 65          53      MN  Limited Free              SPECTRUM
# 66          54      MN  Limited Free              SPECTRUM
# 67          55      MN  Limited Free              SPECTRUM
# 68          56      MN  Limited Free              SPECTRUM
# 69          57      MN  Limited Free              SPECTRUM
# 70          58      MN  Limited Free              SPECTRUM
# 71          59      MN  Limited Free              SPECTRUM
# 72          60      MN  Limited Free              SPECTRUM
# 73          61      MN  Limited Free              SPECTRUM
# 95         129      MN  Limited Free              SPECTRUM
# 96         130      MN  Limited Free              SPECTRUM
# 97         131      MN  Limited Free              SPECTRUM
# 98         132      MN  Limited Free              SPECTRUM
# 99         133      MN  Limited Free              SPECTRUM
# ...

# %%
nycwifi[nycwifi['Name'] == 'Hansborough Recreation Center']
# Out:
#       OBJECTID Borough          Type  Provider                           Name  \
# 67          55      MN  Limited Free  SPECTRUM  Hansborough Recreation Center
# 68          56      MN  Limited Free  SPECTRUM  Hansborough Recreation Center
# 69          57      MN  Limited Free  SPECTRUM  Hansborough Recreation Center
# 70          58      MN  Limited Free  SPECTRUM  Hansborough Recreation Center
# 71          59      MN  Limited Free  SPECTRUM  Hansborough Recreation Center
# 72          60      MN  Limited Free  SPECTRUM  Hansborough Recreation Center
# 73          61      MN  Limited Free  SPECTRUM  Hansborough Recreation Center
# 1554      2111      MN  Limited Free  SPECTRUM  Hansborough Recreation Center
#
#                                 Location   Latitude  Longitude             X  \
# 67    3rd Floor Computer Resource Center  40.812681 -73.939357  1.001037e+06
# 68            3rd Floor Basketball Court  40.812681 -73.939357  1.001037e+06
# ...

# %%
nycwifi[(nycwifi['Borough'] == 'BK') | (nycwifi['Borough'] == 'BX')]
# Out:
#       OBJECTID Borough          Type              Provider             Name  \
# 12           1      BK  Limited Free             ALTICEUSA     Wingate Park
# 13           2      BK  Limited Free             ALTICEUSA     Wingate Park
# 15           3      BK  Limited Free             ALTICEUSA     Wingate Park
# 16           4      BK  Limited Free             ALTICEUSA     Wingate Park
# 17           5      BK  Limited Free             ALTICEUSA     Wingate Park
# 18           6      BX  Limited Free             ALTICEUSA  Pelham Bay Park
# 19           7      BX  Limited Free             ALTICEUSA  Pelham Bay Park
# 20           8      BX  Limited Free             ALTICEUSA  Pelham Bay Park
# 21           9      BX  Limited Free             ALTICEUSA  Pelham Bay Park
# 22          10      BX  Limited Free             ALTICEUSA  Pelham Bay Park
# 23          11      BX  Limited Free             ALTICEUSA  Pelham Bay Park
# ...

# %%
nycwifi.describe()
# Out:
#           OBJECTID     Latitude    Longitude             X              Y  \
# count  3179.000000  3179.000000  3179.000000  3.179000e+03    3179.000000
# mean   4686.602705    40.742141   -73.948829  9.984257e+05  209668.951880
# std    3280.501946     0.067330     0.062305  1.727490e+04   24528.184114
# min       1.000000    40.509531   -74.244107  9.163706e+05  125007.163094
# 25%    1242.500000    40.695590   -73.984828  9.884544e+05  192723.009675
# 50%    6890.000000    40.746619   -73.959775  9.954000e+05  211290.335985
# 75%    7684.500000    40.793669   -73.926740  1.004530e+06  228438.271192
# max    8652.000000    40.903723   -73.714838  1.063266e+06  268543.647017
#
#           BoroCode     CounDist      Postcode       BoroCD         CT2010  \
# count  3179.000000  3179.000000   3179.000000  3179.000000    3179.000000
# mean      2.136206    17.570620  10512.166405   220.938660    2366.161372
# std       1.271019    14.830985    848.728384   128.196638   12678.996423
# ...

# %%
nycwifi[nycwifi['Type'] == 'Free']
# Out:
#       OBJECTID Borough  Type              Provider  \
# 0         8641      QU  Free      Spot On Networks
# 1         8642      QU  Free      Spot On Networks
# 2         8643      QU  Free      Spot On Networks
# 3         8644      QU  Free      Spot On Networks
# 4         8645      QU  Free      Spot On Networks
# 5         8646      QU  Free      Spot On Networks
# 6         8647      QU  Free      Spot On Networks
# 7         8648      QU  Free      Spot On Networks
# 8         8649      QU  Free      Spot On Networks
# 9         8650      QU  Free      Spot On Networks
# 10        8651      QU  Free      Spot On Networks
# 11        8652      QU  Free      Spot On Networks
# 14         474      MN  Free                Harlem
# 78          66      BK  Free                 NYCHA
# 79          67      BK  Free                 NYCHA
# 80          68      BK  Free                 NYCHA
# 81          69      BK  Free                 NYCHA
# ...

# %%
nycwifi.groupby('Type').count()
# Out:
#               OBJECTID  Borough  Provider  Name  Location  Latitude  \
# Type
# Free              2596     2596      2596  2338      2596      2596
# Limited Free       581      581       581   581       581       581
# Partner Site         2        2         2     2         2         2
#
#               Longitude     X     Y  Location_T          ...           \
# Type                                                     ...
# Free               2596  2596  2596        2596          ...
# Limited Free        581   581   581         581          ...
# Partner Site          2     2     2           2          ...
#
#               NTAName  CounDist  Postcode  BoroCD  CT2010  BCTCB2010   BIN  \
# Type
# Free             2596      2596      2596    2596    2596       2596  2596
# Limited Free      581       581       581     581     581        581   581
# Partner Site        2         2         2       2       2          2     2
#
#                BBL  DOITT_ID  Location (Lat, Long)
# ...

# %%
nycwifi.groupby('Provider').count()
# Out:
#                          OBJECTID  Borough  Type  Name  Location  Latitude  \
# Provider
# ALTICEUSA                     237      237   237   237       237       237
# AT&T                           27       27    27    27        27        27
# BPL                            59       59    59    59        59        59
# Chelsea                        30       30    30     0        30        30
# City Tech                      11       11    11    11        11        11
# Downtown Brooklyn             100      100   100     0       100       100
# Harlem                        128      128   128     0       128       128
# LinkNYC - Citybridge         1731     1731  1731  1731      1731      1731
# Manhattan Down Alliance        36       36    36    36        36        36
# NYCHA                          28       28    28    28        28        28
# NYPL                           90       90    90    90        90        90
# ...

# %%
nycwifi.iloc[5] # locates specific row in dataset
# Out:
# OBJECTID                                                          8646
# Borough                                                             QU
# Type                                                              Free
# Provider                                              Spot On Networks
# Name                    QUEENS BRIDGE - JACOB A. RIIS Settlement House
# Location                                               10-05 41 AVENUE
# Latitude                                                       40.7558
# Longitude                                                     -73.9452
# X                                                               999442
# Y                                                               214622
# Location_T                          Indoor AP - North Maintenance Area
# Remarks                              Free - Up to 25 mbs Wi-Fi Service
# City                                                            Queens
# ...

# %%
nycwifi.iloc[5, 1] # specific row and column
# Out:
# 'QU'

# %%
nycwifi.iloc[[5, 105, 205], 1] # can use lists
# Out:
# 5      QU
# 105    MN
# 205    MN
# Name: Borough, dtype: object

# %%
nycwifi.Borough.describe()
# Out:
# count     3179
# unique       5
# top         MN
# freq      1577
# Name: Borough, dtype: object

# %%
nycwifi.Remarks.describe()
# Out:
# count                                                 2608
# unique                                                 280
# top       Tablet Internet -phone , Free 1 GB Wi-FI Service
# freq                                                  1731
# Name: Remarks, dtype: object

# %%
nycwifi.groupby('Remarks').count()
# Out:
#                                                   OBJECTID  Borough  Type  \
# Remarks
# 3 free 10 min sessions                                 580      580   580
# Free - Up to 25 mbs Wi-Fi Service                       16       16    16
# SN 10                                                    1        1     1
# SN 102                                                   1        1     1
# SN 103                                                   1        1     1
# SN 104                                                   1        1     1
# SN 105                                                   1        1     1
# SN 106                                                   1        1     1
# SN 107                                                   1        1     1
# SN 11                                                    1        1     1
# SN 115                                                   1        1     1
# ...
