# %% [markdown]
# # Week 4 / Day 5 / Web Scraping Intro

# %%
# %%HTML
# <h1>Heading</h1>
# <p>This is a paragraph <strong>work!!</strong></p>
# Out:
# <h1>Heading</h1>
# <p>This is a paragraph <strong>work!!</strong></p>

# %% [markdown]
# ---
# ### yelp.com - Search for falafel in New York

# %%
url = 'https://www.yelp.com/search?find_desc=falafel&find_loc=New+York%2C+NY&ns=1'

# %%
from bs4 import BeautifulSoup
import requests

# %%
response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
response.text[:100]
# Out:
# '<!DOCTYPE HTML>\n\n<!--[if lt IE 7 ]> <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie6 ie'

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
soup.find('span')
# Out:
# <span class="pseudo-input_text">Find</span>

# %%
soup.find_all('span')
# Out:
# [<span class="pseudo-input_text">Find</span>,
#  <span class="pseudo-input_field-holder">
#  <input aria-autocomplete="list" autocomplete="off" class="main-search_field pseudo-input_field" id="find_desc" maxlength="64" name="find_desc" placeholder="tacos, cheap dinner, Max’s" tabindex="1" value="falafel"/>
#  </span>,
#  <span class="pseudo-input_text">Near</span>,
#  <span class="main-search_field-holder pseudo-input_field-holder">
#  <input aria-autocomplete="list" autocomplete="off" class="main-search_field pseudo-input_field" data-query="New York, NY" id="dropperText_Mast" maxlength="80" name="find_loc" placeholder="address, neighborhood, city, state or zip" tabindex="2" value="New York, NY"/>
#  <input name="ns" type="hidden" value="1"/>
#  </span>,
#  <span class="main-search_action-icon-wrap js-search-icon-wrap">
#  <span aria-hidden="true" class="icon icon--24-search icon--size-24 icon--inverse icon--fallback-inverted" style="width: 24px; height: 24px;">
# ...

# %%
soup.find('a', {'data-analytics-label': 'biz-name'}).text
# Out:
# 'First Oasis'

# %%
rests = soup.find_all('a', {'data-analytics-label': 'biz-name'})

# %%
for rest in rests:
    print(rest.text)
# Out:
# First Oasis
# Mamoun’s Falafel
# Taim West Village
# Falafix
# Nish Nush
# Taim Nolita
# Mamoun’s Falafel
# Sam’s Falafel Stand
# Nish Nush
# Queen of Falafel
# Heights Falafel
# Oasis
# Pahal Zan
# Darna Falafel
# Pita Palace
# Chick P
# Zaytoun
# Ba’al Cafe & Falafel
# Pita Point
# Zyara NY
# Panorama
# Bedouin Tent
# The Chick Shop
# Murray’s Falafel
# Mr Falafel
# Falafapita Marine Park
# King of Falafel & Shawarma - Restaurant
# La Goulette
# King of Falafel & Shawarma - Cart
# Kulushkat Gourmet Falafel
# Zatar
