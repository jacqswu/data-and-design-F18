# %% [markdown]
# # Week 3 / Day 4 / Mapping Data with Folium
#
# ![](images/folium.png)
#
# Below, we will go through a brief introduction to the **Folium** library.  This is a nice way to build interactive visuzlizations.  We will be executing these in the jupyter notebooks, however they are easily output as `.html` files ready to be served.  To begin, let's make sure we have folium installed.

# %%
import folium
import pandas as pd

# %% [markdown]
# ### We can make basic maps centered at any geolocation.  For example, below we create a basic map of Los Angeles, CA.

# %%
m = folium.Map(location=[34.052235, -118.243683], zoom_start = 12)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m.save('index_map.html')

# %% [markdown]
# ### We can add arguments that include changing the style of the map and the initial zoom level.
# [Map style templates](https://deparkes.co.uk/2016/06/10/folium-map-tiles/)

# %%
folium.Map(
    location=[34.020012, -117.949509],
    tiles='Stamen Toner',
    zoom_start=13
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### We can use the `popup` argument to include information to be displayed at specified marker locations.

# %%
tooltip = 'Click me!'
m = folium.Map(
    location=[45.372, -121.6972],
    zoom_start=12,
    tiles='Stamen Terrain'
)



folium.Marker([45.3288, -121.6625], popup='<i>Mt. Hood Meadows</i>').add_to(m)
folium.Marker([45.3311, -121.7113], popup='<b>Timberline Lodge</b>').add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### We can even include `markdown` syntax and icons.

# %%
m = folium.Map(
    location=[45.372, -121.6972],
    zoom_start=12,
    tiles='Stamen Terrain'
)

folium.Marker(
    location=[45.3288, -121.6625],
    popup='Mt. Hood Meadows',
    icon=folium.Icon(icon='cloud')
).add_to(m)

folium.Marker(
    location=[45.3311, -121.7113],
    popup='Timberline Lodge',
    icon=folium.Icon(color='green')
).add_to(m)

folium.Marker(
    location=[45.3300, -121.6823],
    popup='Some Other Location',
    icon=folium.Icon(color='red', icon='info-sign')
).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### We can manually control radii for markers of interest.  Below, we plot two circles at specific locations.

# %%
m = folium.Map(
    location=[45.5236, -122.6750],
    tiles='Stamen Toner',
    zoom_start=13
)

folium.Circle(
    radius=100,
    location=[45.5244, -122.6699],
    popup='The Waterfront',
    color='crimson',
    fill=False,
).add_to(m)

folium.CircleMarker(
    location=[45.5215, -122.6261],
    radius=50,
    popup='Laurelhurst Park',
    color='#3186cc',
    fill=True,
    fill_color='#3186cc'
).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ---
# ## Problem

# %%
gardens = pd.read_json('https://data.cityofnewyork.us/resource/yes4-7zbb.json')

# %%
gardens.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 536 entries, 0 to 535
# Data columns (total 17 columns):
# address             535 non-null object
# bbl                 431 non-null object
# bin                 431 non-null object
# boro                536 non-null object
# census_tract        429 non-null float64
# community_board     536 non-null object
# council_district    495 non-null float64
# cross_streets       464 non-null object
# garden_name         536 non-null object
# jurisdiction        536 non-null object
# latitude            429 non-null float64
# longitude           429 non-null float64
# neighborhoodname    323 non-null object
# nta                 431 non-null object
# postcode            431 non-null object
# propid              536 non-null object
# size                536 non-null object
# dtypes: float64(4), object(13)
# memory usage: 71.3+ KB

# %%
garden_map = gardens[(gardens.latitude.isna() == False) & (gardens.longitude.isna() == False)]

# %%
garden_map.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 429 entries, 0 to 535
# Data columns (total 17 columns):
# address             429 non-null object
# bbl                 429 non-null object
# bin                 429 non-null object
# boro                429 non-null object
# census_tract        429 non-null float64
# community_board     429 non-null object
# council_district    403 non-null float64
# cross_streets       368 non-null object
# garden_name         429 non-null object
# jurisdiction        429 non-null object
# latitude            429 non-null float64
# longitude           429 non-null float64
# neighborhoodname    265 non-null object
# nta                 429 non-null object
# postcode            429 non-null object
# propid              429 non-null object
# size                429 non-null object
# dtypes: float64(4), object(13)
# memory usage: 60.3+ KB

# %%
m = folium.Map(location = [garden_map.latitude[0], garden_map.longitude[0]], tiles='Stamen Toner',)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
for index, row in garden_map.iterrows():
    folium.CircleMarker(location=(row["latitude"],
                                  row["longitude"]),
                        radius = 1.0,
                        color='blue',
                        fill=True).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# - What information should be included about the gardens? ***Garden name and address***
# - Can you alter the loop above to have this information available by scrolling over a point?

# %%
garden_map = gardens[(gardens.latitude.isna() == False) & (gardens.longitude.isna() == False) & (gardens.garden_name.isna() == False) & (gardens.address.isna() == False)]

# %%
#popup_text = """{}<br>
# address: {}"""

#popup_text = popup_text.format(row[gardens.garden_name])
#                               , row[gardens.address]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-109-151b74a59526> in <module>()
#       2 #                address: {}"""
#       3
# ----> 4 popup_text = popup_text.format(row[gardens.garden_name]
#       5 #                               , row[gardens.address]
#       6                               )
#
# IndexError: tuple index out of range

# %%
popup_text = row[gardens.garden_name]

# %%
popup_text
# Out:
# garden_name
# 11 BC Serenity Garden                                                 NaN
# 1100 Bergen Street Community Garden                                   NaN
# 110th Street Block Association                                        NaN
# 117th Street Community Garden                                         NaN
# 11th Street Community Garden                                          NaN
# 211th Street Block Association.                                       NaN
# 2120 Mapes Avenue HDFC                                                NaN
# 400 Montauk Avenue Block Association. (Ismael Vega y Amigos)          NaN
# 5th Street Slope Garden Club                                          NaN
# 6/15 Green                                                            NaN
# 64th Street Community Garden                                          NaN
# 6BC Botanical Garden                                                  NaN
# 6th Street & Avenue B Garden                                          NaN
# 700 Decatur Street Block Association                                  NaN
# 811 Family and Friends Association                                    NaN
# 97th Street Block Association                                         NaN
# 9th Street Community Garden & Park                                    NaN
# A Better Community Garden                                             NaN
# A. Badillo Community Rose Garden                                      NaN
# Aberdeen Street II Garden Projects                                    NaN
# Abib Newborn                                                          NaN
# Adlai E. Stevenson High School-Ecological Garden                      NaN
# Alberts Garden                                                        NaN
# All People's Church of the Apostolic Faith Community Garden           NaN
# All Peoples Garden, Inc.                                              NaN
# Amazing Garden                                                        NaN
# Amboy St. Garden                                                      NaN
# American Heart                                                        NaN
# Angie Lee-Gonzalez & Luis Gonzalez Garden                             NaN
# Anthony Avenue Garden                                                 NaN
#                                                                      ...
# Vernon (Throop Avenue Block Assoc.)                                   NaN
# Vernon New Harvest                                                    NaN
# Vernon T&T Block Assoc.                                               NaN
# Victory Garden                                                        NaN
# Victory Garden - Crotona Park                                         NaN
# Victory Gardens Group                                                 NaN
# Villa Santurce Jardinera - 112th Street                               NaN
# Villa Santurce Jardineras - Park Avenue                               NaN
# Vogue Community Garden                                                NaN
# Walt L. Shamal Community Garden                                       NaN
# Walton High School                                                    NaN
# Wanaqua Garden                                                        NaN
# Warren-St.Marks Community Garden                                      NaN
# Waterfront Community Garden                                           NaN
# Welcome Home Garden                                                   NaN
# West 104th Street Garden                                              NaN
# West 111th Street People's Garden                                     NaN
# West 124th Street Community Garden                                    NaN
# West 131st Street Community Garden                                    NaN
# West 132nd Street Garden                                              NaN
# West 181st Street Beautification Project                              NaN
# West 87th Street Park & Garden                                        NaN
# Westbrook Memorial Garden                                             NaN
# Westervelt Community & Family Garden                                  NaN
# William A. Harris Garden                                              NaN
# William B. Washington Memorial Garden                                 NaN
# Williams Avenue Community Garden (formerly Shaw Block Association)    NaN
# Wishing Well Garden                                                   NaN
# Woodbine St. Block Assoc.                                             NaN
# Woodycrest Community Garden                                           NaN
# Name: 0, Length: 536, dtype: object

# %%
for index, row in garden_map.iterrows():
    folium.CircleMarker(
        location=(row["latitude"], row["longitude"]),
        radius = 1.0,
        color='blue',
        fill=True,
        popup=row[gardens.garden_name]).add_to(m)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-115-d47b81821cbc> in <module>()
#       5         color='blue',
#       6         fill=True,
# ----> 7         popup=row[gardens.garden_name]).add_to(m)
#
# /anaconda3/lib/python3.6/site-packages/folium/vector_layers.py in __init__(self, location, radius, popup, tooltip, **kwargs)
#     325     def __init__(self, location, radius=10, popup=None, tooltip=None, **kwargs):
#     326         super(CircleMarker, self).__init__(location=location, popup=popup,
# --> 327                                            tooltip=tooltip)
#     328         self._name = 'CircleMarker'
#     329         self.options = _parse_options(line=False, radius=radius, **kwargs)
#
# /anaconda3/lib/python3.6/site-packages/folium/map.py in __init__(self, location, popup, tooltip, icon)
#     254             self.add_child(Popup(popup))
#     255         elif popup is not None:
# --> 256             self.add_child(popup)
#     257         if isinstance(tooltip, Tooltip):
#     258             self.add_child(tooltip)
#
# /anaconda3/lib/python3.6/site-packages/branca/element.py in add_child(self, child, name, index)
#      98         """Add a child."""
#      99         if name is None:
# --> 100             name = child.get_name()
#     101         if index is None:
#     102             self._children[name] = child
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'get_name'

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Mapping Bike Data
#
# Now, we will use a dataset from NYC's citibike data.  Our goal is to compare incoming and outgoing traffic at given stations depending on the time of day.

# %%
folium_map = folium.Map(location=[40.738, -73.98],
                        zoom_start=13,
                        tiles="CartoDB dark_matter")
marker = folium.CircleMarker(location=[40.738, -73.98])
marker.add_to(folium_map)

# %%
folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
bikes = pd.read_csv('data/201306-citibike-tripdata.csv')

# %%
bikes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 577703 entries, 0 to 577702
# Data columns (total 15 columns):
# tripduration               577703 non-null int64
# starttime                  577703 non-null object
# stoptime                   577703 non-null object
# start station id           577703 non-null int64
# start station name         577703 non-null object
# start station latitude     577703 non-null float64
# start station longitude    577703 non-null float64
# end station id             559644 non-null float64
# end station name           559644 non-null object
# end station latitude       559644 non-null float64
# end station longitude      559644 non-null float64
# bikeid                     577703 non-null int64
# usertype                   577703 non-null object
# birth year                 337382 non-null float64
# gender                     577703 non-null int64
# dtypes: float64(6), int64(4), object(5)
# memory usage: 66.1+ MB

# %%
bikes['starttime'] = pd.to_datetime(bikes['starttime'])
bikes['stoptime'] = pd.to_datetime(bikes['stoptime'])
bikes['hour'] = bikes['starttime'].map(lambda x: x.hour)
bikes['ehour'] = bikes['stoptime'].map(lambda x: x.hour)

# %%
bikes.head()
# Out:
#    tripduration           starttime            stoptime  start station id  \
# 0           695 2013-06-01 00:00:01 2013-06-01 00:11:36               444
# 1           693 2013-06-01 00:00:08 2013-06-01 00:11:41               444
# 2          2059 2013-06-01 00:00:44 2013-06-01 00:35:03               406
# 3           123 2013-06-01 00:01:04 2013-06-01 00:03:07               475
# 4          1521 2013-06-01 00:01:22 2013-06-01 00:26:43              2008
#
#        start station name  start station latitude  start station longitude  \
# 0      Broadway & W 24 St               40.742354               -73.989151
# 1      Broadway & W 24 St               40.742354               -73.989151
# 2  Hicks St & Montague St               40.695128               -73.995951
# 3     E 15 St & Irving Pl               40.735243               -73.987586
# 4   Little West St & 1 Pl               40.705693               -74.016777
#
#    end station id        end station name  end station latitude  \
# 0           434.0         9 Ave & W 18 St             40.743174
# 1           434.0         9 Ave & W 18 St             40.743174
# 2           406.0  Hicks St & Montague St             40.695128
# 3           262.0         Washington Park             40.691782
# 4           310.0     State St & Smith St             40.689269
#
#    end station longitude  bikeid    usertype  birth year  gender  hour  ehour
# 0             -74.003664   19678  Subscriber      1983.0       1     0      0
# 1             -74.003664   16649  Subscriber      1984.0       1     0      0
# 2             -73.995951   19599    Customer         NaN       0     0      0
# 3             -73.973730   16352  Subscriber      1960.0       1     0      0
# 4             -73.989129   15567  Subscriber      1983.0       1     0      0

# %%
locations = bikes.groupby('start station id').first()

# %%
locations = locations.loc[:, ["start station latitude", "start station longitude", "start station name"]]

# %%
locations
# Out:
#                   start station latitude  start station longitude  \
# start station id
# 72                             40.767272               -73.993929
# 79                             40.719116               -74.006667
# 82                             40.711174               -74.000165
# 83                             40.683826               -73.976323
# 116                            40.741776               -74.001497
# 119                            40.696089               -73.978034
# 120                            40.686768               -73.959282
# 127                            40.731724               -74.006744
# 128                            40.727103               -74.002971
# 137                            40.761628               -73.972924
# 143                            40.692395               -73.993379
# 144                            40.698399               -73.980689
# 146                            40.716250               -74.009106
# 147                            40.715422               -74.011220
# 150                            40.720874               -73.980858
# 151                            40.722104               -73.997249
# 152                            40.714740               -74.009106
# 153                            40.752062               -73.981632
# 157                            40.690893               -73.996123
# 160                            40.748158               -73.978462
# 161                            40.729170               -73.998102
# 164                            40.753231               -73.970325
# 167                            40.748901               -73.976049
# 168                            40.739713               -73.994564
# 173                            40.760683               -73.984527
# 174                            40.738177               -73.977387
# 195                            40.709056               -74.010434
# 212                            40.743349               -74.006818
# 216                            40.700379               -73.995481
# 217                            40.702772               -73.993836
# ...                                  ...                      ...
# 532                            40.710451               -73.960876
# 533                            40.752996               -73.987216
# 534                            40.702551               -74.012723
# 536                            40.741444               -73.975361
# 537                            40.740259               -73.984092
# 538                            40.756660               -73.976684
# 539                            40.715348               -73.960241
# 540                            40.743116               -73.982154
# 545                            40.736502               -73.978095
# 546                            40.744449               -73.983035
# 2000                           40.702551               -73.989402
# 2001                           40.699773               -73.979927
# 2002                           40.716887               -73.963198
# 2003                           40.733812               -73.980544
# 2004                           40.724399               -74.004704
# 2005                           40.705312               -73.971001
# 2006                           40.765909               -73.976342
# 2008                           40.705693               -74.016777
# 2009                           40.711174               -73.996826
# 2010                           40.721655               -74.002347
# 2012                           40.739445               -73.976806
# 2021                           40.759291               -73.988597
# 2022                           40.759107               -73.959223
# 2023                           40.759681               -73.970314
# 3000                           40.755467               -73.986536
# 3002                           40.711512               -74.015756
# 3014                           40.722852               -73.959114
# 3017                           40.751483               -73.996764
# 3019                           40.716633               -73.981933
# 3020                           40.646607               -74.015970
#
#                                               start station name
# start station id
# 72                                              W 52 St & 11 Ave
# 79                                      Franklin St & W Broadway
# 82                                        St James Pl & Pearl St
# 83                                 Atlantic Ave & Fort Greene Pl
# 116                                              W 17 St & 8 Ave
# 119                                     Park Ave & St Edwards St
# 120                                  Lexington Ave & Classon Ave
# 127                                        Barrow St & Hudson St
# 128                                     MacDougal St & Prince St
# 137                                        E 56 St & Madison Ave
# 143                                    Clinton St & Joralemon St
# 144                                          Nassau St & Navy St
# 146                                         Hudson St & Reade St
# 147                                     Greenwich St & Warren St
# 150                                            E 2 St & Avenue C
# 151                                     Cleveland Pl & Spring St
# 152                                        Warren St & Church St
# 153                                              E 40 St & 5 Ave
# 157                                      Henry St & Atlantic Ave
# 160                                      E 37 St & Lexington Ave
# 161                                        LaGuardia Pl & W 3 St
# 164                                              E 47 St & 2 Ave
# 167                                              E 39 St & 3 Ave
# 168                                              W 18 St & 6 Ave
# 173                                           Broadway & W 49 St
# 174                                              E 25 St & 1 Ave
# 195                                        Liberty St & Broadway
# 212                                      W 16 St & The High Line
# 216                              Columbia Heights & Cranberry St
# 217                                                Old Fulton St
# ...                                                          ...
# 532                                              S 5 Pl & S 5 St
# 533                                           Broadway & W 38 St
# 534                                      Water - Whitehall Plaza
# 536                                              1 Ave & E 30 St
# 537                                      Lexington Ave & E 24 St
# 538                                        E 48 St & Madison Ave
# 539                               Metropolitan Ave & Bedford Ave
# 540                                      Lexington Ave & E 29 St
# 545                                              E 23 St & 1 Ave
# 546                                         E 30 St & Park Ave S
# 2000                                    Front St & Washington St
# 2001                                          Sands St & Navy St
# 2002                                Wythe Ave & Metropolitan Ave
# 2003                                             1 Ave & E 18 St
# 2004                                           6 Ave & Broome St
# 2005                                      Railroad Ave & Kay Ave
# 2006                                      Central Park S & 6 Ave
# 2008                                       Little West St & 1 Pl
# 2009                                    Catherine St & Monroe St
# 2010                                        Grand St & Greene St
# 2012                                             E 27 St & 1 Ave
# 2021                                             W 45 St & 8 Ave
# 2022                                          E 60 St & York Ave
# 2023                                     E 55 St & Lexington Ave
# 3000                                                   MLSWKiosk
# 3002                                  South End Ave & Liberty St
# 3014              3969.TEMP (Bike The Branches - Central Branch)
# 3017                                           NYCBS Depot - FAR
# 3019                                           NYCBS Depot - DEL
# 3020                                                  NYCBS Test
#
# [337 rows x 3 columns]

# 988                -74.008387   15257  Subscriber      1985.0       1    10
# 989                       NaN   18099  Subscriber      1968.0       1    10
# 990                -73.981693   18874    Customer         NaN       0    10
# 991                -73.976687   20240  Subscriber      1967.0       2    10
# 992                -73.989111   16031  Subscriber      1966.0       1    10
# 993                -73.983688   19240  Subscriber      1977.0       1    10
# 994                -73.959223   15254    Customer         NaN       0    10
# 995                -73.991908   17747  Subscriber      1978.0       2    10
# 996                -73.994800   16170  Subscriber      1966.0       2    10
# 997                -73.987834   18259  Subscriber      1986.0       1    10
# 998                -74.006667   17959  Subscriber      1972.0       1    10
# 999                -73.986580   15715  Subscriber      1984.0       1    10
# 1000               -73.982050   16988  Subscriber      1949.0       2    10
# 1001               -73.990093   16838  Subscriber      1966.0       1    10
# 1002               -73.989978   15325  Subscriber      1976.0       1    10
# 1003               -73.981013   15423  Subscriber      1980.0       1    10
# 1004               -73.990741   17091  Subscriber      1976.0       1    10
# 1005               -73.976684   20290  Subscriber      1976.0       1    10
# 1006               -74.002971   18997  Subscriber      1989.0       2    10
# 1007               -73.983688   16103  Subscriber      1983.0       2    10
# 1008               -74.002116   19504    Customer         NaN       0    10
# 1009               -73.997047   20159  Subscriber      1959.0       1    10
# ...                       ...     ...         ...         ...     ...   ...
# 557327                    NaN   19234    Customer         NaN       0    10
# 557328             -74.013221   19917  Subscriber      1982.0       1    10
# 557329             -74.012342   18839    Customer         NaN       0    10
# 557330             -73.982681   20239  Subscriber      1984.0       2    10
# 557331             -73.981693   15841  Subscriber      1982.0       1    10
# 557332                    NaN   15870    Customer         NaN       0    10
# 557333             -73.987520   20115  Subscriber      1978.0       1    10
# 557334             -73.997249   20030  Subscriber      1985.0       2    10
# 557335             -73.998512   14658    Customer         NaN       0    10
# 557336             -74.008119   19034  Subscriber      1980.0       2    10
# 557337             -73.990931   19564  Subscriber      1968.0       1    10
# 557338             -73.988484   14895  Subscriber      1976.0       1    10
# 557339             -73.984284   16574  Subscriber      1963.0       1    10
# 557340             -74.002150   15311    Customer         NaN       0    10
# 557341             -73.996224   15494  Subscriber      1956.0       1    10
# 557342             -73.980858   14972  Subscriber      1983.0       1    10
# 557343             -73.991580   16179  Subscriber      1971.0       2    10
# 557344             -74.000271   17433    Customer         NaN       0    10
# 557345             -74.012342   17519    Customer         NaN       0    10
# 557346             -73.981693   20518    Customer         NaN       0    10
# 557347             -73.991026   19481  Subscriber      1986.0       1    10
# 557348             -73.989151   17202    Customer         NaN       0    10
# 557349             -73.990541   19981  Subscriber      1966.0       1    10
# 557351             -73.989780   16684  Subscriber      1979.0       2    10
# 557352             -73.988900   16843  Subscriber      1976.0       1    10
# 557385             -73.980144   14911  Subscriber      1962.0       1    10
# 557397             -73.998522   15809  Subscriber      1975.0       1    10
# 557409             -73.996224   15153  Subscriber      1962.0       2    10
# 557419             -74.000264   18290  Subscriber      1971.0       1    10
# 557561             -73.995653   16004  Subscriber      1951.0       1    10
#
#         ehour
# 980        11
# 981        10
# 982        10
# 983        10
# 984        10
# 985        10
# 986        10
# 987        10
# 988        10
# 989        10
# 990        11
# 991        10
# 992        10
# 993        10
# 994        10
# 995        10
# 996        10
# 997        10
# 998        10
# 999        10
# 1000       10
# 1001       10
# 1002       10
# 1003       10
# 1004       10
# 1005       10
# 1006       10
# 1007       10
# 1008       10
# 1009       10
# ...       ...
# 557327     11
# 557328     11
# 557329     11
# 557330     11
# 557331     11
# 557332     11
# 557333     11
# 557334     11
# 557335     11
# 557336     11
# 557337     11
# 557338     11
# 557339     11
# 557340     11
# 557341     11
# 557342     11
# 557343     11
# 557344     11
# 557345     11
# 557346     11
# 557347     11
# 557348     11
# 557349     11
# 557351     11
# 557352     11
# 557385     11
# 557397     11
# 557409     11
# 557419     11
# 557561     11
#
# [23137 rows x 17 columns]

# %%
dept_counts = subset.groupby("start station id").count()

# %%
dept_counts = dept_counts.iloc[:, [0]]

# %%
dept_counts.columns = ["Departure Counts"]

# %%
dept_counts
# Out:
#                   Departure Counts
# start station id
# 72                              80
# 79                             117
# 82                              25
# 83                              44
# 116                            115
# 119                              7
# 120                             20
# 127                            178
# 128                             73
# 137                              9
# 143                             60
# 144                             19
# 146                             73
# 147                            103
# 150                            105
# 151                            115
# 152                             70
# 153                             18
# 157                             48
# 160                             13
# 161                             98
# 164                             65
# 167                             79
# 168                             75
# 173                            104
# 174                             71
# 195                             85
# 212                             86
# 216                             31
# 217                             51
# ...                            ...
# 530                            133
# 531                             49
# 532                             57
# 533                             81
# 534                             37
# 536                            112
# 537                            106
# 538                             49
# 539                             69
# 540                             93
# 545                            109
# 546                             58
# 2000                            36
# 2002                            54
# 2003                            98
# 2004                            61
# 2005                             8
# 2006                           260
# 2008                            41
# 2009                            27
# 2010                            28
# 2012                            55
# 2021                            26
# 2022                            38
# 2023                            30
# 3002                            29
# 3014                             3
# 3017                            31
# 3019                            11
# 3020                             8
#
# [335 rows x 1 columns]

# %% [markdown]
# ### Problem
#
# Repeat the above for arrivals, in anticipation of joining the two for our map.

# %%
bikes['hour'] = bikes['starttime'].map(lambda x: x.hour)

locations = locations.loc[:, ["start station latitude", "start station longitude", "start station name"]]
subset = bikes[bikes["hour"]==18]
dept_counts = subset.groupby("start station id").count()
dept_counts = dept_counts.iloc[:, [0]]
dept_counts.columns = ["Departure Counts"]

locations2 = bikes.groupby('end station id').first()
locations2 = locations2.loc[:, ["end station latitude", "end station longitude", "end station name"]]
subset = bikes[bikes["ehour"]==18]
arr_counts = subset.groupby("end station id").count()
arr_counts = arr_counts.iloc[:, [0]]
arr_counts.columns = ["Arrival Counts"]

# %%
trip_counts = dept_counts.join(locations).join(arr_counts)

# %%
trip_counts.head()
# Out:
#                   Departure Counts  start station latitude  \
# start station id
# 72                             187               40.767272
# 79                             403               40.719116
# 82                              76               40.711174
# 83                             111               40.683826
# 116                            215               40.741776
#
#                   start station longitude             start station name  \
# start station id
# 72                             -73.993929               W 52 St & 11 Ave
# 79                             -74.006667       Franklin St & W Broadway
# 82                             -74.000165         St James Pl & Pearl St
# 83                             -73.976323  Atlantic Ave & Fort Greene Pl
# 116                            -74.001497                W 17 St & 8 Ave
#
#                   Arrival Counts
# start station id
# 72                           198
# 79                           342
# 82                            74
# 83                           142
# 116                          213

# %%
for index, row in trip_counts.iterrows():
    
    net_departures = (row["Departure Counts"]-row["Arrival Counts"])
    
    radius = net_departures/7
    
    if net_departures>0:
        color="#E37222" # tangerine
    else:
        color="#0A8A9F" # teal
    
    folium.CircleMarker(location=(row["start station latitude"],
                                  row["start station longitude"]),
                        radius=radius,
                        color=color,
                        fill=True).add_to(folium_map)

# %%
folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
popup_text = """{}<br>
                total departures: {}<br> 
                total arrivals: {}<br>
                net departures: {}"""
 
popup_text = popup_text.format(row["start station name"],
                               row["Arrival Counts"],
                               row["Departure Counts"],
                               net_departures)

# %%
for index, row in trip_counts.iterrows():
   
    popup_text = row["start station name"]

# %%
popup_text
# Out:
# 'NYCBS Test'

# %%
for index, row in trip_counts.iterrows():
    net_departures = (row["Departure Counts"]-row["Arrival Counts"])
    radius = net_departures/7
    if net_departures>0:
        color="#E37222" # tangerine
    else:
        color="#0A8A9F" # teal
    
    folium.CircleMarker(location=(row["start station latitude"],
                                  row["start station longitude"]),
                        radius=radius,
                        color=color,
                        fill=True, popup = popup_text).add_to(folium_map)

# %%
folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### PROBLEM
#
# Compare this image to that of when people are leaving work.  Doe you see what you expect?  What does this tell you about movement in the city?

# %%
subset2 = bikes[bikes["hour"]==18]
subset2
# Out:
#         tripduration           starttime            stoptime  \
# 5848            1140 2013-06-01 18:00:19 2013-06-01 18:19:19
# 5850            3631 2013-06-01 18:00:41 2013-06-01 19:01:12
# 5851            1105 2013-06-01 18:00:54 2013-06-01 18:19:19
# 5852             497 2013-06-01 18:00:42 2013-06-01 18:08:59
# 5853             498 2013-06-01 18:01:00 2013-06-01 18:09:18
# 5854             436 2013-06-01 18:01:14 2013-06-01 18:08:30
# 5855             200 2013-06-01 18:01:17 2013-06-01 18:04:37
# 5856            1534 2013-06-01 18:01:26 2013-06-01 18:27:00
# 5857             287 2013-06-01 18:01:26 2013-06-01 18:06:13
# 5858             397 2013-06-01 18:01:45 2013-06-01 18:08:22
# 5859             102 2013-06-01 18:01:46 2013-06-01 18:03:28
# 5860             458 2013-06-01 18:01:52 2013-06-01 18:09:30
# 5861             721 2013-06-01 18:02:02 2013-06-01 18:14:03
# 5862             446 2013-06-01 18:01:57 2013-06-01 18:09:23
# 5863             953 2013-06-01 18:02:05 2013-06-01 18:17:58
# 5864             339 2013-06-01 18:02:08 2013-06-01 18:07:47
# 5865            1695 2013-06-01 18:02:01 2013-06-01 18:30:16
# 5867            2401 2013-06-01 18:02:14 2013-06-01 18:42:15
# 5868             464 2013-06-01 18:02:27 2013-06-01 18:10:11
# 5869            1086 2013-06-01 18:02:28 2013-06-01 18:20:34
# 5870             823 2013-06-01 18:02:37 2013-06-01 18:16:20
# 5871            2322 2013-06-01 18:02:46 2013-06-01 18:41:28
# 5872             717 2013-06-01 18:02:51 2013-06-01 18:14:48
# 5860                  72                 W 52 St & 11 Ave
# 5861                 120      Lexington Ave & Classon Ave
# 5862                3019                NYCBS Depot - DEL
# 5863                  79         Franklin St & W Broadway
# 5864                 265         Stanton St & Chrystie St
# 5865                 426            West St & Chambers St
# 5867                 434                  9 Ave & W 18 St
# 5868                 497               E 17 St & Broadway
# 5869                 493              W 45 St & 6 Ave (1)
# 5870                 168                  W 18 St & 6 Ave
# 5871                 238          Bank St & Washington St
# 5872                 375        Mercer St & Bleecker St S
# 5873                 401          Allen St & Rivington St
# 5874                 150                E 2 St & Avenue C
# 5875                 304            Broadway & Battery Pl
# 5876                 345                  W 13 St & 6 Ave
# 5877                 474                  5 Ave & E 29 St
# 5878                 304            Broadway & Battery Pl
# 5879                 238          Bank St & Washington St
# ...                  ...                              ...
# 572244               509                  9 Ave & W 22 St
# 572245               489                 10 Ave & W 28 St
# 572246               444               Broadway & W 24 St
# 572247               315         South St & Gouverneur Ln
# 572248               456            E 53 St & Madison Ave
# 572249                72                 W 52 St & 11 Ave
# 572250               447                  8 Ave & W 52 St
# 572251               368               Carmine St & 6 Ave
# 572252               368               Carmine St & 6 Ave
# 572253               402               Broadway & E 22 St
# 572254               533               Broadway & W 38 St
# 572255               128         MacDougal St & Prince St
# 572256               402               Broadway & E 22 St
# 572257               530                 11 Ave & W 59 St
# 572258               317                E 6 St & Avenue B
# 572259               324          DeKalb Ave & Hudson Ave
# 572260               296             Division St & Bowery
# 572261               263         Elizabeth St & Hester St
# 572263               348           W Broadway & Spring St
# 572271               401          Allen St & Rivington St
# 572292               489                 10 Ave & W 28 St
# 572314               447                  8 Ave & W 52 St
# 572335               151         Cleveland Pl & Spring St
# 572344               254                  W 11 St & 6 Ave
# 572357               258      DeKalb Ave & Vanderbilt Ave
# 572367               147         Greenwich St & Warren St
# 572397               477                  W 41 St & 8 Ave
# 572401               515                 W 43 St & 10 Ave
# 572605               515                 W 43 St & 10 Ave
# 572758               505                  6 Ave & W 33 St
#
#         start station latitude  start station longitude  end station id  \
# 5848                 40.727791               -73.985649           433.0
# 5850                 40.762288               -73.983362           500.0
# 5851                 40.727791               -73.985649           342.0
# 5852                 40.737050               -73.990093           380.0
# 5853                 40.722174               -73.983688           310.0
# 5854                 40.700379               -73.995481           233.0
# 5855                 40.742354               -73.989151           402.0
# 5856                 40.769155               -73.981918           353.0
# 5857                 40.739355               -73.999318           453.0
# 5858                 40.700379               -73.995481           233.0
# 5859                 40.740343               -73.989551           402.0
# 5860                 40.767272               -73.993929           500.0
# 5861                 40.686768               -73.959282           310.0
# 5862                 40.716633               -73.981933           500.0
# 5863                 40.719116               -74.006667           314.0
# 5864                 40.722293               -73.991475           229.0
# 5865                 40.717548               -74.013221           525.0
# 5867                 40.743174               -74.003664           406.0
# 5868                 40.737050               -73.990093           494.0
# 5869                 40.756800               -73.982912           465.0
# 5870                 40.739713               -73.994564           401.0
# 5871                 40.736197               -74.008592           439.0
# 5872                 40.726795               -73.996951           540.0
# 5873                 40.720196               -73.989978           268.0
# 572244             -73.973715   17519  Subscriber      1987.0       1    18
# 572245             -74.009660   17600  Subscriber      1980.0       1    18
# 572246             -73.983035   15725  Subscriber      1984.0       2    18
# 572247             -74.008592   18394    Customer         NaN       0    18
# 572248             -73.988021   16466    Customer         NaN       0    18
# 572249             -74.006667   20577  Subscriber      1981.0       2    18
# 572250             -73.976342   16210    Customer         NaN       0    18
# 572251             -73.967416   16215  Subscriber      1980.0       1    18
# 572252             -73.973736   16247  Subscriber      1980.0       1    18
# 572253             -73.992663   15770    Customer         NaN       0    18
# 572254             -73.995101   20160  Subscriber      1972.0       1    18
# 572255             -74.002638   16658  Subscriber      1978.0       1    18
# 572256             -73.981693   18736  Subscriber      1980.0       1    18
# 572257             -73.991026   16144  Subscriber      1954.0       2    18
# 572258             -73.986923   17295  Subscriber      1983.0       1    18
# 572259             -74.004831   18016    Customer         NaN       0    18
# 572260             -73.988900   15502    Customer         NaN       0    18
# 572261             -74.002345   15961    Customer         NaN       0    18
# 572263             -74.002150   20244  Subscriber      1977.0       1    18
# 572271             -73.989551   17291  Subscriber      1990.0       1    18
# 572292             -74.009660   17200  Subscriber      1983.0       1    18
# 572314             -73.997262   19971  Subscriber      1955.0       2    18
# 572335             -73.985180   16325  Subscriber      1986.0       1    18
# 572344             -73.990741   15070  Subscriber      1982.0       2    18
# 572357             -73.983390   17151  Subscriber      1983.0       1    18
# 572367             -73.997047   19101  Subscriber      1970.0       1    18
# 572397             -73.990931   16784  Subscriber      1965.0       2    18
# 572401             -73.995299   15373  Subscriber      1987.0       2    18
# 572605             -73.986905   17894  Subscriber      1997.0       1    18
# 572758             -73.973442   20330  Subscriber      1984.0       2    18
#
#         ehour
# 5848       18
# 5850       19
# 5851       18
# 5852       18
# 5853       18
# 5854       18
# 5855       18
# 5856       18
# 5857       18
# 5858       18
# 5859       18
# 5860       18
# 5861       18
# 5862       18
# 5863       18
# 5864       18
# 5865       18
# 5867       18
# 5868       18
# 5869       18
# 5870       18
# 5871       18
# 5872       18
# 5873       18
# 5874       23
# 5875       18
# 5876       18
# 5877       18
# 5878       18
# 5879       18
# ...       ...
# 572244     19
# 572245     19
# 572246     19
# 572247     19
# 572248     19
# 572249     19
# 572250     20
# 572251     19
# 572252     19
# 572253     19
# 572254     19
# 572255     19
# 572256     19
# 572257     19
# 572258     19
# 572259     19
# 572260     19
# 572261     19
# 572263     19
# 572271     19
# 572292     19
# 572314     19
# 572335     19
# 572344     19
# 572357     19
# 572367     19
# 572397     19
# 572401     19
# 572605     19
# 572758     19
#
# [53915 rows x 17 columns]

# %%
dept_counts2 = subset2.groupby("start station id").count()

# %%
dept_counts2 = dept_counts2.iloc[:, [0]]

# %%
dept_counts2.columns = ["Departure Counts"]

# %%
locations2 = bikes.groupby('end station id').first()
locations2 = locations2.loc[:, ["end station latitude", "end station longitude", "end station name"]]
subset = bikes[bikes["hour"]==10]
arr_counts = subset.groupby("end station id").count()
arr_counts = arr_counts.iloc[:, [0]]
arr_counts.columns = ["Arrival Counts"]
